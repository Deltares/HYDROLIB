# %%
from cmt.project import Project
from pathlib import Path
from hydrolib.core.io.bc.models import ForcingModel

# %%
stochastics_json = Path(r"../data/dellen/populate_cases.json")
project = Project(filepath=r"../data/stochast").from_stochastics(stochastics_json)

# %%
project.dict()
# Out:
# {'filepath': WindowsPath('D:/repositories/HYDROLIB/contrib/d2hydro/data/stochast'),
#  'boundary_conditions': {'meteo': [{'id': '24H_85MM_HOOG_WINTER',
#     'name': '24H_85MM_HOOG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_70MM_HOOG_WINTER',
#     'name': '24H_70MM_HOOG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_60MM_HOOG_WINTER',
#     'name': '24H_60MM_HOOG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_50MM_HOOG_WINTER',
#     'name': '24H_50MM_HOOG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_40MM_HOOG_WINTER',
#     'name': '24H_40MM_HOOG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_30MM_HOOG_WINTER',
#     'name': '24H_30MM_HOOG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_20MM_HOOG_WINTER',
#     'name': '24H_20MM_HOOG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_85MM_LAAG_WINTER',
#     'name': '24H_85MM_LAAG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_70MM_LAAG_WINTER',
#     'name': '24H_70MM_LAAG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_60MM_LAAG_WINTER',
#     'name': '24H_60MM_LAAG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_50MM_LAAG_WINTER',
#     'name': '24H_50MM_LAAG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_40MM_LAAG_WINTER',
#     'name': '24H_40MM_LAAG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_30MM_LAAG_WINTER',
#     'name': '24H_30MM_LAAG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_20MM_LAAG_WINTER',
#     'name': '24H_20MM_LAAG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_85MM_MIDDELHOOG_WINTER',
#     'name': '24H_85MM_MIDDELHOOG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_70MM_MIDDELHOOG_WINTER',
#     'name': '24H_70MM_MIDDELHOOG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_60MM_MIDDELHOOG_WINTER',
#     'name': '24H_60MM_MIDDELHOOG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_50MM_MIDDELHOOG_WINTER',
#     'name': '24H_50MM_MIDDELHOOG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_40MM_MIDDELHOOG_WINTER',
#     'name': '24H_40MM_MIDDELHOOG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_30MM_MIDDELHOOG_WINTER',
#     'name': '24H_30MM_MIDDELHOOG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_20MM_MIDDELHOOG_WINTER',
#     'name': '24H_20MM_MIDDELHOOG_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_95MM_HOOG_ZOMER',
#     'name': '24H_95MM_HOOG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_85MM_HOOG_ZOMER',
#     'name': '24H_85MM_HOOG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_70MM_HOOG_ZOMER',
#     'name': '24H_70MM_HOOG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_60MM_HOOG_ZOMER',
#     'name': '24H_60MM_HOOG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_50MM_HOOG_ZOMER',
#     'name': '24H_50MM_HOOG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_40MM_HOOG_ZOMER',
#     'name': '24H_40MM_HOOG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_30MM_HOOG_ZOMER',
#     'name': '24H_30MM_HOOG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_20MM_HOOG_ZOMER',
#     'name': '24H_20MM_HOOG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_95MM_LAAG_ZOMER',
#     'name': '24H_95MM_LAAG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_85MM_LAAG_ZOMER',
#     'name': '24H_85MM_LAAG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_70MM_LAAG_ZOMER',
#     'name': '24H_70MM_LAAG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_60MM_LAAG_ZOMER',
#     'name': '24H_60MM_LAAG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_50MM_LAAG_ZOMER',
#     'name': '24H_50MM_LAAG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_40MM_LAAG_ZOMER',
#     'name': '24H_40MM_LAAG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_30MM_LAAG_ZOMER',
#     'name': '24H_30MM_LAAG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_20MM_LAAG_ZOMER',
#     'name': '24H_20MM_LAAG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_95MM_MIDDELHOOG_ZOMER',
#     'name': '24H_95MM_MIDDELHOOG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_85MM_MIDDELHOOG_ZOMER',
#     'name': '24H_85MM_MIDDELHOOG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_70MM_MIDDELHOOG_ZOMER',
#     'name': '24H_70MM_MIDDELHOOG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_60MM_MIDDELHOOG_ZOMER',
#     'name': '24H_60MM_MIDDELHOOG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_50MM_MIDDELHOOG_ZOMER',
#     'name': '24H_50MM_MIDDELHOOG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_40MM_MIDDELHOOG_ZOMER',
#     'name': '24H_40MM_MIDDELHOOG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_30MM_MIDDELHOOG_ZOMER',
#     'name': '24H_30MM_MIDDELHOOG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': '24H_20MM_MIDDELHOOG_ZOMER',
#     'name': '24H_20MM_MIDDELHOOG_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')}],
#   'flow': [{'id': 'NIET_VERHOOGD_WINTER',
#     'name': 'NIET_VERHOOGD_WINTER',
#     'start_datetime': Timestamp('2000-01-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')},
#    {'id': 'NIET_VERHOOGD_ZOMER',
#     'name': 'NIET_VERHOOGD_ZOMER',
#     'start_datetime': Timestamp('2000-06-01 00:00:00'),
#     'timedelta': Timedelta('1 days 00:00:00')}]},
#  'initial_conditions': {'rr': [{'id': 'hydrowinterhalfyear_middelnat',
#     'name': 'hydrowinterhalfyear_middelnat'},
#    {'id': 'hydrosummerhalfyear_middelnat',
#     'name': 'hydrosummerhalfyear_middelnat'}],
#   'flow': []},
#  'models': [{'id': 'D-Hydro-model',
#    'name': 'D-Hydro-model',
#    'mdu': 'dflowfm/dellen.mdu',
#    'fnm': 'RR/Sobek_3b.fnm'}],
#  'cases': [{'id': 'STOWA2014_HUIDIG_winter_middelnat_KORT_85mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_KORT_85mm_niet_verhoogd',
#    'meteo_bc_id': '24H_85MM_HOOG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_KORT_70mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_KORT_70mm_niet_verhoogd',
#    'meteo_bc_id': '24H_70MM_HOOG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_KORT_60mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_KORT_60mm_niet_verhoogd',
#    'meteo_bc_id': '24H_60MM_HOOG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_KORT_50mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_KORT_50mm_niet_verhoogd',
#    'meteo_bc_id': '24H_50MM_HOOG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_KORT_40mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_KORT_40mm_niet_verhoogd',
#    'meteo_bc_id': '24H_40MM_HOOG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_KORT_30mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_KORT_30mm_niet_verhoogd',
#    'meteo_bc_id': '24H_30MM_HOOG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_KORT_20mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_KORT_20mm_niet_verhoogd',
#    'meteo_bc_id': '24H_20MM_HOOG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_LAAG_85mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_LAAG_85mm_niet_verhoogd',
#    'meteo_bc_id': '24H_85MM_LAAG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_LAAG_70mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_LAAG_70mm_niet_verhoogd',
#    'meteo_bc_id': '24H_70MM_LAAG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_LAAG_60mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_LAAG_60mm_niet_verhoogd',
#    'meteo_bc_id': '24H_60MM_LAAG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_LAAG_50mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_LAAG_50mm_niet_verhoogd',
#    'meteo_bc_id': '24H_50MM_LAAG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_LAAG_40mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_LAAG_40mm_niet_verhoogd',
#    'meteo_bc_id': '24H_40MM_LAAG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_LAAG_30mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_LAAG_30mm_niet_verhoogd',
#    'meteo_bc_id': '24H_30MM_LAAG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_LAAG_20mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_LAAG_20mm_niet_verhoogd',
#    'meteo_bc_id': '24H_20MM_LAAG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_MIDDELHOOG_85mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_MIDDELHOOG_85mm_niet_verhoogd',
#    'meteo_bc_id': '24H_85MM_MIDDELHOOG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_MIDDELHOOG_70mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_MIDDELHOOG_70mm_niet_verhoogd',
#    'meteo_bc_id': '24H_70MM_MIDDELHOOG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_MIDDELHOOG_60mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_MIDDELHOOG_60mm_niet_verhoogd',
#    'meteo_bc_id': '24H_60MM_MIDDELHOOG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_MIDDELHOOG_50mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_MIDDELHOOG_50mm_niet_verhoogd',
#    'meteo_bc_id': '24H_50MM_MIDDELHOOG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_MIDDELHOOG_40mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_MIDDELHOOG_40mm_niet_verhoogd',
#    'meteo_bc_id': '24H_40MM_MIDDELHOOG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_MIDDELHOOG_30mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_MIDDELHOOG_30mm_niet_verhoogd',
#    'meteo_bc_id': '24H_30MM_MIDDELHOOG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_winter_middelnat_MIDDELHOOG_20mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_winter_middelnat_MIDDELHOOG_20mm_niet_verhoogd',
#    'meteo_bc_id': '24H_20MM_MIDDELHOOG_WINTER',
#    'flow_bc_id': 'NIET_VERHOOGD_WINTER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-01-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_KORT_95mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_KORT_95mm_niet_verhoogd',
#    'meteo_bc_id': '24H_95MM_HOOG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_KORT_85mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_KORT_85mm_niet_verhoogd',
#    'meteo_bc_id': '24H_85MM_HOOG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_KORT_70mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_KORT_70mm_niet_verhoogd',
#    'meteo_bc_id': '24H_70MM_HOOG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_KORT_60mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_KORT_60mm_niet_verhoogd',
#    'meteo_bc_id': '24H_60MM_HOOG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_KORT_50mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_KORT_50mm_niet_verhoogd',
#    'meteo_bc_id': '24H_50MM_HOOG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_KORT_40mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_KORT_40mm_niet_verhoogd',
#    'meteo_bc_id': '24H_40MM_HOOG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_KORT_30mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_KORT_30mm_niet_verhoogd',
#    'meteo_bc_id': '24H_30MM_HOOG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_KORT_20mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_KORT_20mm_niet_verhoogd',
#    'meteo_bc_id': '24H_20MM_HOOG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_LAAG_95mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_LAAG_95mm_niet_verhoogd',
#    'meteo_bc_id': '24H_95MM_LAAG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_LAAG_85mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_LAAG_85mm_niet_verhoogd',
#    'meteo_bc_id': '24H_85MM_LAAG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_LAAG_70mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_LAAG_70mm_niet_verhoogd',
#    'meteo_bc_id': '24H_70MM_LAAG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_LAAG_60mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_LAAG_60mm_niet_verhoogd',
#    'meteo_bc_id': '24H_60MM_LAAG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_LAAG_50mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_LAAG_50mm_niet_verhoogd',
#    'meteo_bc_id': '24H_50MM_LAAG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_LAAG_40mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_LAAG_40mm_niet_verhoogd',
#    'meteo_bc_id': '24H_40MM_LAAG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_LAAG_30mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_LAAG_30mm_niet_verhoogd',
#    'meteo_bc_id': '24H_30MM_LAAG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_LAAG_20mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_LAAG_20mm_niet_verhoogd',
#    'meteo_bc_id': '24H_20MM_LAAG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_MIDDELHOOG_95mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_MIDDELHOOG_95mm_niet_verhoogd',
#    'meteo_bc_id': '24H_95MM_MIDDELHOOG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_MIDDELHOOG_85mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_MIDDELHOOG_85mm_niet_verhoogd',
#    'meteo_bc_id': '24H_85MM_MIDDELHOOG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_MIDDELHOOG_70mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_MIDDELHOOG_70mm_niet_verhoogd',
#    'meteo_bc_id': '24H_70MM_MIDDELHOOG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_MIDDELHOOG_60mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_MIDDELHOOG_60mm_niet_verhoogd',
#    'meteo_bc_id': '24H_60MM_MIDDELHOOG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_MIDDELHOOG_50mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_MIDDELHOOG_50mm_niet_verhoogd',
#    'meteo_bc_id': '24H_50MM_MIDDELHOOG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_MIDDELHOOG_40mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_MIDDELHOOG_40mm_niet_verhoogd',
#    'meteo_bc_id': '24H_40MM_MIDDELHOOG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_MIDDELHOOG_30mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_MIDDELHOOG_30mm_niet_verhoogd',
#    'meteo_bc_id': '24H_30MM_MIDDELHOOG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}},
#   {'id': 'STOWA2014_HUIDIG_zomer_middelnat_MIDDELHOOG_20mm_niet_verhoogd',
#    'name': 'STOWA2014_HUIDIG_zomer_middelnat_MIDDELHOOG_20mm_niet_verhoogd',
#    'meteo_bc_id': '24H_20MM_MIDDELHOOG_ZOMER',
#    'flow_bc_id': 'NIET_VERHOOGD_ZOMER',
#    'model_id': 'D-Hydro-model',
#    'fm_output_dir': WindowsPath('output'),
#    'start_datetime': Timestamp('2000-06-01 00:00:00'),
#    'simulation_period': Timedelta('1 days 00:00:00'),
#    'run': {'completed': False,
#     'success': None,
#     'start_datetime': None,
#     'run_duration': None,
#     'results_id': 'D-Hydro-model',
#     'output_deleted': None}}],
#  'results': [{'id': 'D-Hydro-model',
#    'statistic': 'max',
#    'samples': [{'id': 'ObservationPoint_KST-O-17700',
#      'name': 'ObservationPoint_KST-O-17700',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17700',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17800',
#      'name': 'ObservationPoint_KST-O-17800',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17800',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17680',
#      'name': 'ObservationPoint_KST-O-17680',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17680',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17685',
#      'name': 'ObservationPoint_KST-O-17685',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17685',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17690',
#      'name': 'ObservationPoint_KST-O-17690',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17690',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17750',
#      'name': 'ObservationPoint_KST-O-17750',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17750',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17755',
#      'name': 'ObservationPoint_KST-O-17755',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17755',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17760',
#      'name': 'ObservationPoint_KST-O-17760',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17760',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17710',
#      'name': 'ObservationPoint_KST-O-17710',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17710',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17730',
#      'name': 'ObservationPoint_KST-O-17730',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17730',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17740',
#      'name': 'ObservationPoint_KST-O-17740',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17740',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17660',
#      'name': 'ObservationPoint_KST-O-17660',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17660',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17670',
#      'name': 'ObservationPoint_KST-O-17670',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17670',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17770',
#      'name': 'ObservationPoint_KST-O-17770',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17770',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17780',
#      'name': 'ObservationPoint_KST-O-17780',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17780',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17820',
#      'name': 'ObservationPoint_KST-O-17820',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17820',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17650',
#      'name': 'ObservationPoint_KST-O-17650',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17650',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17790',
#      'name': 'ObservationPoint_KST-O-17790',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17790',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_KST-O-17810',
#      'name': 'ObservationPoint_KST-O-17810',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_KST-O-17810',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_PMP_KGM-O-11860',
#      'name': 'ObservationPoint_PMP_KGM-O-11860',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_PMP_KGM-O-11860',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}},
#     {'id': 'ObservationPoint_PMP_KGM-O-11730',
#      'name': 'ObservationPoint_PMP_KGM-O-11730',
#      'source': {'nc_file': 'his',
#       'id': 'ObservationPoint_PMP_KGM-O-11730',
#       'layer': 'station',
#       'variable': 'water level',
#       'statistic': 'max'}}],
#    'results': {}}]}

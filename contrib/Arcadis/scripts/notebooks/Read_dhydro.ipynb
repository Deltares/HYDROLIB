# %% [markdown]
# # Lees D-HYDRO bestanden in
#
# Deze notebook laat zien hoe verschillende D-Hydro bestanden kunnen worden ingelezen met het read_dhydro.py script. De verschillende cellen gaan in op wat er wordt ingelezen en hoe dit gebruikt kan worden.
#
# Dit script heeft vijf inputs nodig:
# * `net_nc_path`: Pad naar input nc-file met het D-Hydro netwerk
# * `map_nc_path`: Pad naar input map-file met de D-Hydro map resultaten.
# * `his_nc_path`: Pad naar input his-file met de D-Hydro his resultaten.
# * `mdu_path`: Pad naar input mdu-file met het D-Hydro model
# * `output_path`: Pad naar folder om resultaten weg te schrijven.
#
# Opmerkingen:
# -  Hydrolib dient in python geïnstalleerd te zijn (open prompt, pip install hydrolib-core)
# -  De gebruiker dient een map "C:\temp\Hydrolib" te hebben.

# %%
import os 
import sys
from pathlib import Path
currentdir = os.path.dirname(os.path.abspath(''))
sys.path.insert(0,currentdir) 
from read_dhydro import net_nc2gdf, map_nc2gdf,hisnc_2gdf,chainage2gdf,branch_gui2df,read_nc_data, pli2gdf, read_locations

# %%
# Dit zijn de inputs die benodigd zijn voor dit script.
net_nc_path = os.path.join(
    currentdir, r"exampledata\Dellen\Model\dflowfm\dellen_net.nc"
)
map_nc_path = os.path.join(
    currentdir, r"exampledata\Dellen\Model\dflowfm\output\Flow1D_map.nc"
)
his_nc_path = os.path.join(
    currentdir, r"exampledata\Dellen\Model\dflowfm\output\Flow1D_his.nc"
)
mdu_path = os.path.join(
    currentdir, r"exampledata\Dellen\Model_cleaned\dflowfm\Flow1D.mdu"
)
output_path = "C:/temp/HYDROLIB"

# %% [markdown]
# # Lees *_net.nc bestanden in

# %%
results = [
        "1d_meshnodes",
        "1d_nodes",
        "1d_branches",
        "1d_edges",
        "2d_nodes",
        "2d_edges",
        "2d_faces",
        "1d2d_links",
    ]

# %% [markdown]
# #### Het Dellen model bevat alleen 1D onderdelen. Daarom worden hieronder 1D onderdelen ingeladen.

# %%
network = net_nc2gdf(
    net_nc_path,
    results
)
meshnodes = network['1d_meshnodes']
nodes = network['1d_meshnodes']
branches = network['1d_meshnodes']
edges = network['1d_meshnodes']
# Out:
# Amersfoort aangenomen als projectie
# no 1d2d links in model
# Aangenomen dat alle lijnen watergangen zijn, branches.gui is leeg.

# %%
## Run hier verschillende functies om te kijken wat er in de data staat.
meshnodes
# nodes
# branches
# edges
# Out:
#                       id                 name  branch       offset  \
# 0       OAF-O-00216_0.00     OAF-O-00216_0.00       0     0.000000
# 1       OAF-O-00216_1.10     OAF-O-00216_1.10       0     1.099139
# 2       OAF-O-02381_0.00     OAF-O-02381_0.00       1     0.000000
# 3       OAF-O-02381_2.46     OAF-O-02381_2.46       1     2.464982
# 4       OAF-O-00213_0.00     OAF-O-00213_0.00       2     0.000000
# ..                   ...                  ...     ...          ...
# 648  OAF-O-00099_1206.78  OAF-O-00099_1206.78     170  1206.776082
# 649  OAF-O-00099_1307.34  OAF-O-00099_1307.34     170  1307.340756
# 650  OAF-O-00099_1407.91  OAF-O-00099_1407.91     170  1407.905429
# 651  OAF-O-00099_1508.47  OAF-O-00099_1508.47     170  1508.470103
# 652  OAF-O-00099_1609.03  OAF-O-00099_1609.03     170  1609.034776
#
#                           geometry
# 0    POINT (252081.429 579840.300)
# 1    POINT (252081.438 579841.399)
# 2    POINT (251353.320 576355.418)
# 3    POINT (251353.956 576357.800)
# 4    POINT (252066.886 579841.778)
# ..                             ...
# 648  POINT (253037.753 582076.953)
# 649  POINT (253115.292 582139.542)
# 650  POINT (253210.094 582172.911)
# 651  POINT (253305.232 582205.475)
# 652  POINT (253398.546 582242.902)
#
# [653 rows x 5 columns]

# %% [markdown]
# # Lees *_map.nc bestanden in
#
# Output van dit bestand geeft een GeoDataFrame met op de rijen de meetpunten en op de kolommen de tijdstappen.

# %%
param = "mesh1d_waterdepth"
map_nc2gdf(map_nc_path, "mesh1d_waterdepth")
# Out:
# Geen projectie in het model, Amersfoort aangenomen
# The possible parameters are:
#  ['mesh1d_node_branch', 'mesh1d_node_offset', 'mesh1d_node_x', 'mesh1d_node_y', 'mesh1d_edge_branch', 'mesh1d_edge_offset', 'mesh1d_edge_x', 'mesh1d_edge_y', 'mesh1d_node_id', 'mesh1d_node_long_name', 'mesh1d_edge_nodes', 'mesh1d_FlowElemContour_x', 'mesh1d_FlowElemContour_y', 'mesh1d_flowelem_ba', 'mesh1d_flowelem_bl', 'mesh1d_Numlimdt', 'mesh1d_s1', 'mesh1d_s0', 'mesh1d_negdpt', 'mesh1d_negdpt_cum', 'mesh1d_noiter', 'mesh1d_noiter_cum', 'mesh1d_limtstep', 'mesh1d_limtstep_cum', 'mesh1d_courant', 'mesh1d_waterdepth', 'mesh1d_u1', 'mesh1d_u0', 'mesh1d_ucx', 'mesh1d_ucy', 'mesh1d_ucmag', 'mesh1d_q1', 'mesh1d_viu', 'mesh1d_diu', 'mesh1d_taus', 'mesh1d_czs', 'mesh1d_czu', 'mesh1d_time_water_on_ground', 'mesh1d_freeboard', 'mesh1d_waterdepth_on_ground', 'mesh1d_volume_on_ground', 'mesh1d_current_total_net_inflow_1d2d', 'mesh1d_cumulative_total_net_inflow_1d2d', 'mesh1d_current_total_net_inflow_lateral', 'mesh1d_cumulative_total_net_inflow_lateral', []]
#                      1951-01-01 00:00:00  1951-01-01 00:10:00  \
# OAF-O-00216_0.00                    1.00             0.907836
# OAF-O-00216_1.10                    1.00             1.487265
# OAF-O-02381_0.00                    1.00             0.474721
# OAF-O-02381_2.46                    1.00             1.884384
# OAF-O-00213_0.00                    1.46             0.643888
# ...                                  ...                  ...
# OAF-O-00099_1206.78                 1.00             1.050786
# OAF-O-00099_1307.34                 1.00             1.041332
# OAF-O-00099_1407.91                 1.00             1.031795
# OAF-O-00099_1508.47                 1.00             1.017640
# OAF-O-00099_1609.03                 1.00             0.991935
#
#                      1951-01-01 00:20:00  1951-01-01 00:30:00  \
# OAF-O-00216_0.00                1.071525             1.174668
# OAF-O-00216_1.10                1.651026             1.754350
# OAF-O-02381_0.00                0.544358             0.611422
# OAF-O-02381_2.46                1.954338             2.021421
# OAF-O-00213_0.00                0.745081             0.772610
# ...                                  ...                  ...
# OAF-O-00099_1206.78             1.087954             1.133287
# OAF-O-00099_1307.34             1.071930             1.119095
# OAF-O-00099_1407.91             1.056307             1.104661
# OAF-O-00099_1508.47             1.041400             1.090725
# OAF-O-00099_1609.03             1.026706             1.077405
#
#                      1951-01-01 00:40:00  1951-01-01 00:50:00  \
# OAF-O-00216_0.00                1.219573             1.253439
# OAF-O-00216_1.10                1.799351             1.833279
# OAF-O-02381_0.00                0.668423             0.716190
# OAF-O-02381_2.46                2.078430             2.126189
# OAF-O-00213_0.00                0.783908             0.791947
# ...                                  ...                  ...
# OAF-O-00099_1206.78             1.164305             1.197469
# OAF-O-00099_1307.34             1.152393             1.187962
# OAF-O-00099_1407.91             1.140608             1.178757
# OAF-O-00099_1508.47             1.129267             1.170152
# OAF-O-00099_1609.03             1.118198             1.161983
#
#                      1951-01-01 01:00:00  1951-01-01 01:10:00  \
# OAF-O-00216_0.00                1.274407             1.283757
# OAF-O-00216_1.10                1.854280             1.863584
# OAF-O-02381_0.00                0.753686             0.781779
# OAF-O-02381_2.46                2.163684             2.191778
# OAF-O-00213_0.00                0.797090             0.733878
# ...                                  ...                  ...
# OAF-O-00099_1206.78             1.234481             1.272861
# OAF-O-00099_1307.34             1.227438             1.267698
# OAF-O-00099_1407.91             1.220751             1.262855
# OAF-O-00099_1508.47             1.214642             1.258485
# OAF-O-00099_1609.03             1.208965             1.254429
#
#                      1951-01-01 01:20:00  1951-01-01 01:30:00  ...  \
# OAF-O-00216_0.00                1.291561             1.292805  ...
# OAF-O-00216_1.10                1.870548             1.872713  ...
# OAF-O-02381_0.00                0.801467             0.813932  ...
# OAF-O-02381_2.46                2.211467             2.223932  ...
# OAF-O-00213_0.00                0.526821             0.747577  ...
# ...                                  ...                  ...  ...
# OAF-O-00099_1206.78             1.308108             1.337329  ...
# OAF-O-00099_1307.34             1.303941             1.333699  ...
# OAF-O-00099_1407.91             1.299992             1.330248  ...
# OAF-O-00099_1508.47             1.296370             1.327062  ...
# OAF-O-00099_1609.03             1.292955             1.324046  ...
#
#                      1951-01-07 22:40:00  1951-01-07 22:50:00  \
# OAF-O-00216_0.00                2.075028             2.075903
# OAF-O-00216_1.10                2.655028             2.655903
# OAF-O-02381_0.00                1.052780             1.053584
# OAF-O-02381_2.46                2.462780             2.463584
# OAF-O-00213_0.00                3.111980             3.112879
# ...                                  ...                  ...
# OAF-O-00099_1206.78             4.133552             4.134455
# OAF-O-00099_1307.34             4.133551             4.134453
# OAF-O-00099_1407.91             4.133549             4.134452
# OAF-O-00099_1508.47             4.133548             4.134451
# OAF-O-00099_1609.03             4.133547             4.134450
#
#                      1951-01-07 23:00:00  1951-01-07 23:10:00  \
# OAF-O-00216_0.00                2.076776             2.077647
# OAF-O-00216_1.10                2.656776             2.657647
# OAF-O-02381_0.00                1.054387             1.055188
# OAF-O-02381_2.46                2.464387             2.465188
# OAF-O-00213_0.00                3.113776             3.114670
# ...                                  ...                  ...
# OAF-O-00099_1206.78             4.135355             4.136251
# OAF-O-00099_1307.34             4.135353             4.136250
# OAF-O-00099_1407.91             4.135352             4.136249
# OAF-O-00099_1508.47             4.135351             4.136248
# OAF-O-00099_1609.03             4.135350             4.136247
#
#                      1951-01-07 23:20:00  1951-01-07 23:30:00  \
# OAF-O-00216_0.00                2.078515             2.079381
# OAF-O-00216_1.10                2.658515             2.659381
# OAF-O-02381_0.00                1.055987             1.056785
# OAF-O-02381_2.46                2.465987             2.466785
# OAF-O-00213_0.00                3.115562             3.116451
# ...                                  ...                  ...
# OAF-O-00099_1206.78             4.137146             4.138037
# OAF-O-00099_1307.34             4.137144             4.138036
# OAF-O-00099_1407.91             4.137143             4.138035
# OAF-O-00099_1508.47             4.137142             4.138034
# OAF-O-00099_1609.03             4.137141             4.138033
#
#                      1951-01-07 23:40:00  1951-01-07 23:50:00  \
# OAF-O-00216_0.00                2.080244             2.081105
# OAF-O-00216_1.10                2.660244             2.661105
# OAF-O-02381_0.00                1.057581             1.058376
# OAF-O-02381_2.46                2.467581             2.468376
# OAF-O-00213_0.00                3.117337             3.118221
# ...                                  ...                  ...
# OAF-O-00099_1206.78             4.138926             4.139813
# OAF-O-00099_1307.34             4.138925             4.139811
# OAF-O-00099_1407.91             4.138924             4.139810
# OAF-O-00099_1508.47             4.138923             4.139809
# OAF-O-00099_1609.03             4.138922             4.139808
#
#                      1951-01-08 00:00:00                       geometry
# OAF-O-00216_0.00                2.081964  POINT (252081.429 579840.300)
# OAF-O-00216_1.10                2.661964  POINT (252081.438 579841.399)
# OAF-O-02381_0.00                1.059169  POINT (251353.320 576355.418)
# OAF-O-02381_2.46                2.469169  POINT (251353.956 576357.800)
# OAF-O-00213_0.00                3.119102  POINT (252066.886 579841.778)
# ...                                  ...                            ...
# OAF-O-00099_1206.78             4.140697  POINT (253037.753 582076.953)
# OAF-O-00099_1307.34             4.140695  POINT (253115.292 582139.542)
# OAF-O-00099_1407.91             4.140694  POINT (253210.094 582172.911)
# OAF-O-00099_1508.47             4.140693  POINT (253305.232 582205.475)
# OAF-O-00099_1609.03             4.140692  POINT (253398.546 582242.902)
#
# [653 rows x 1010 columns]

# %% [markdown]
# # Lees *_his.nc bestanden in

# %%
strucs = [
    "pump",
    "weirgen",
    "bridge",
    "culvert",
]
hisdata = hisnc_2gdf(his_nc_path, strucs= strucs)
print (hisdata.keys())
# Out:
# Geen projectie in het model, Amersfoort aangenomen
# bedlevel is empty, skipping
# Length is correct.
# Length is correct.
# Length is correct.
# Length is correct.
# dict_keys(['water_balance', 'waterlevel', 'waterdepth', 'taus', 'x_velocity', 'y_velocity', 'velocity_magnitude', 'discharge_magnitude', 'pump', 'weirgen', 'bridge', 'culvert', 'cmpstru', 'lateral'])

# %% [markdown]
# # Lees locaties in met behulp van de .ini bestanden

# %%
read_locations(Path(mdu_path))
# Out:
# Amersfoort aangenomen als projectie
# no 1d2d links in model
# Aangenomen dat alle lijnen watergangen zijn, branches.gui is leeg.
# {'cross_sections_locations':                      id     branchid     chainage  shift  \
#  0       OAF-O-00216_0.1  OAF-O-00216     0.100000    0.0
#  1       OAF-O-00216_1.0  OAF-O-00216     0.999138    0.0
#  2       OAF-O-02381_0.1  OAF-O-02381     0.100000    0.0
#  3       OAF-O-02381_2.4  OAF-O-02381     2.364981    0.0
#  4       OAF-O-00213_0.1  OAF-O-00213     0.100000    0.0
#  ..                  ...          ...          ...    ...
#  244     OAF-O-00059_0.1  OAF-O-00059     0.100000    0.0
#  245  OAF-O-00059_1083.8  OAF-O-00059  1083.801235    0.0
#  246  OAF-O-00111_1032.8  OAF-O-00111  1032.788000    0.0
#  247   OAF-O-00900_989.3  OAF-O-00900   989.274000    0.0
#  248   OAF-O-00099_478.1  OAF-O-00099   478.149000    0.0
#
#                  definitionid       _header locationtype  \
#  0      PPROUP_OAF-O-00216_up  CrossSection           1d
#  1    PPRODN_OAF-O-00216_down  CrossSection           1d
#  2      PPROUP_OAF-O-02381_up  CrossSection           1d
#  3    PPRODN_OAF-O-02381_down  CrossSection           1d
#  4      PPROUP_OAF-O-00213_up  CrossSection           1d
#  ..                       ...           ...          ...
#  244    PPROUP_OAF-O-00059_up  CrossSection           1d
#  245  PPRODN_OAF-O-00059_down  CrossSection           1d
#  246      TB0028-160614131524  CrossSection           1d
#  247      TB0028-160614114327  CrossSection           1d
#  248      TB0028-160615111909  CrossSection           1d
#
#                            geometry
#  0    POINT (252081.430 579840.400)
#  1    POINT (252081.437 579841.299)
#  2    POINT (251353.346 576355.515)
#  3    POINT (251353.930 576357.703)
#  4    POINT (252066.786 579841.780)
#  ..                             ...
#  244  POINT (252387.286 576031.015)
#  245  POINT (251354.023 576357.778)
#  246  POINT (255357.322 583009.478)
#  247  POINT (256749.452 583086.566)
#  248  POINT (253057.581 581389.848)
#
#  [249 rows x 8 columns],
#  'cross_sections_definition':                                               comments  \
#  0    id=None thalweg=None type=None numlevels=None ...
#  1    id=None thalweg=None type=None numlevels=None ...
#  2    id=None thalweg=None type=None numlevels=None ...
#  3    id=None thalweg=None type=None numlevels=None ...
#  4    id=None thalweg=None type=None numlevels=None ...
#  ..                                                 ...
#  398  id=None thalweg=None type=None diameter=None f...
#  399  id=None thalweg=None type=None diameter=None f...
#  400  id=None thalweg=None type=None diameter=None f...
#  401  id=None thalweg=None type=None diameter=None f...
#  402  id=None thalweg=None type=None diameter=None f...
#
#                            id     type  thalweg  numlevels          levels  \
#  0      PPROUP_OAF-O-00216_up  zwRiver      0.0        2.0  [-2.57, -1.74]
#  1    PPRODN_OAF-O-00216_down  zwRiver      0.0        2.0  [-2.57, -1.74]
#  2      PPROUP_OAF-O-02381_up  zwRiver      0.0        2.0  [-1.54, -0.71]
#  3    PPRODN_OAF-O-02381_down  zwRiver      0.0        2.0  [-1.54, -0.71]
#  4      PPROUP_OAF-O-00213_up  zwRiver      0.0        2.0  [-3.15, -2.27]
#  ..                       ...      ...      ...        ...             ...
#  398              KDU-O-01351   circle      0.0        NaN             NaN
#  399              KDU-O-01354   circle      0.0        NaN             NaN
#  400              KDU-O-01355   circle      0.0        NaN             NaN
#  401              KDU-O-01356   circle      0.0        NaN             NaN
#  402              KDU-O-01357   circle      0.0        NaN             NaN
#
#       flowwidths totalwidths  leveecrestLevel  leveebaselevel  ...  conveyance  \
#  0    [0.5, 3.0]  [0.5, 3.0]              NaN             0.0  ...         NaN
#  1    [0.5, 3.0]  [0.5, 3.0]              NaN             0.0  ...         NaN
#  2    [0.5, 3.0]  [0.5, 3.0]              NaN             0.0  ...         NaN
#  3    [0.5, 3.0]  [0.5, 3.0]              NaN             0.0  ...         NaN
#  4    [0.5, 4.0]  [0.5, 4.0]              NaN             0.0  ...         NaN
#  ..          ...         ...              ...             ...  ...         ...
#  398         NaN         NaN              NaN             NaN  ...         NaN
#  399         NaN         NaN              NaN             NaN  ...         NaN
#  400         NaN         NaN              NaN             NaN  ...         NaN
#  401         NaN         NaN              NaN             NaN  ...         NaN
#  402         NaN         NaN              NaN             NaN  ...         NaN
#
#       sectioncount  frictionpositions  diameter  frictionid frictiontype  \
#  0             NaN                NaN       NaN         NaN          NaN
#  1             NaN                NaN       NaN         NaN          NaN
#  2             NaN                NaN       NaN         NaN          NaN
#  3             NaN                NaN       NaN         NaN          NaN
#  4             NaN                NaN       NaN         NaN          NaN
#  ..            ...                ...       ...         ...          ...
#  398           NaN                NaN       0.5         NaN          NaN
#  399           NaN                NaN       0.5         NaN          NaN
#  400           NaN                NaN       0.5         NaN          NaN
#  401           NaN                NaN       0.5         NaN          NaN
#  402           NaN                NaN       0.6         NaN          NaN
#
#       frictionvalue  width height closed
#  0              NaN    NaN    NaN    NaN
#  1              NaN    NaN    NaN    NaN
#  2              NaN    NaN    NaN    NaN
#  3              NaN    NaN    NaN    NaN
#  4              NaN    NaN    NaN    NaN
#  ..             ...    ...    ...    ...
#  398            NaN    NaN    NaN    NaN
#  399            NaN    NaN    NaN    NaN
#  400            NaN    NaN    NaN    NaN
#  401            NaN    NaN    NaN    NaN
#  402            NaN    NaN    NaN    NaN
#
#  [403 rows x 36 columns],
#  'structures':                                   id             name      type     branchid  \
#  0                        KST-O-17660      KST-O-17660      weir  OAF-O-02385
#  1                        KDU-O-00728      KDU-O-00728   culvert  OAF-O-02415
#  2                        KDU-O-01452      KDU-O-01452   culvert  OAF-O-00084
#  3                        KST-O-17690      KST-O-17690      weir  OAF-O-00084
#  4                    PMP_KGM-O-11730  PMP_KGM-O-11730      pump  OAF-O-02479
#  ..                               ...              ...       ...          ...
#  345   CompositeBranchStructure_1D_84               id  compound  OAF-O-00059
#  346   CompositeBranchStructure_1D_85               id  compound  OAF-O-00059
#  347   CompositeBranchStructure_1D_86               id  compound  OAF-O-00059
#  348  CompositeBranchStructure_1D_159               id  compound  OAF-O-00111
#  349  CompositeBranchStructure_1D_174               id  compound  OAF-O-00900
#
#          chainage allowedflowdir  crestlevel  crestwidth  corrcoeff  \
#  0       5.210882           both       -2.03         1.3        1.0
#  1       3.451000           both         NaN         NaN        NaN
#  2       5.179000           both         NaN         NaN        NaN
#  3       0.100000           both       -2.47         0.7        1.0
#  4      11.899886            NaN         NaN         NaN        NaN
#  ..           ...            ...         ...         ...        ...
#  345   949.228000            NaN         NaN         NaN        NaN
#  346  1021.251000            NaN         NaN         NaN        NaN
#  347  1072.161000            NaN         NaN         NaN        NaN
#  348  1152.519186            NaN         NaN         NaN        NaN
#  349  1303.844000            NaN         NaN         NaN        NaN
#
#      usevelocityheight  ... startlevelsuctionside  stoplevelsuctionside  \
#  0                True  ...                   NaN                   NaN
#  1                 NaN  ...                   NaN                   NaN
#  2                 NaN  ...                   NaN                   NaN
#  3                True  ...                   NaN                   NaN
#  4                 NaN  ...               [-3.55]               [-3.65]
#  ..                ...  ...                   ...                   ...
#  345               NaN  ...                   NaN                   NaN
#  346               NaN  ...                   NaN                   NaN
#  347               NaN  ...                   NaN                   NaN
#  348               NaN  ...                   NaN                   NaN
#  349               NaN  ...                   NaN                   NaN
#
#       startleveldeliveryside stopleveldeliveryside  reductionfactor  shift  \
#  0                       NaN                   NaN              NaN    NaN
#  1                       NaN                   NaN              NaN    NaN
#  2                       NaN                   NaN              NaN    NaN
#  3                       NaN                   NaN              NaN    NaN
#  4                     [0.0]                 [0.0]            [1.0]    NaN
#  ..                      ...                   ...              ...    ...
#  345                     NaN                   NaN              NaN    NaN
#  346                     NaN                   NaN              NaN    NaN
#  347                     NaN                   NaN              NaN    NaN
#  348                     NaN                   NaN              NaN    NaN
#  349                     NaN                   NaN              NaN    NaN
#
#       frictiontype friction  numstructures                       geometry
#  0             NaN      NaN            NaN  POINT (251744.377 577507.525)
#  1             NaN      NaN            NaN  POINT (258502.206 585295.056)
#  2             NaN      NaN            NaN  POINT (252072.064 579841.663)
#  3             NaN      NaN            NaN  POINT (252077.142 579841.550)
#  4             NaN      NaN            NaN  POINT (258080.885 584320.320)
#  ..            ...      ...            ...                            ...
#  345           NaN      NaN            1.0  POINT (251482.309 576317.126)
#  346           NaN      NaN            1.0  POINT (251413.631 576338.821)
#  347           NaN      NaN            1.0  POINT (251365.110 576354.232)
#  348           NaN      NaN            1.0  POINT (255455.795 582950.428)
#  349           NaN      NaN            1.0  POINT (257039.793 583207.381)
#
#  [350 rows x 36 columns],
#  'laterals':                                          id locationtype  \
#  0            ucONGEDRAINEERDKLEIGPG-O-17800           1d
#  1       ucAKKERBOUW_TUINBOUWKLEIGPG-O-17800           1d
#  2                 ucGRASLANDKLEIGPG-O-17800           1d
#  3       ucAKKERBOUW_TUINBOUWKLEIGPG-O-17685           1d
#  4            ucONGEDRAINEERDKLEIGPG-O-17685           1d
#  ..                                      ...          ...
#  138     ucAKKERBOUW_TUINBOUWKLEIGPG-O-17690           1d
#  139          ucONGEDRAINEERDVEENGPG-O-17690           1d
#  140  ucBOOM_EN_FRUITKWEKERIJZANDGPG-O-17690           1d
#  141                           gcGPG-O-17690           1d
#  142                           pcGPG-O-17690           1d
#
#                            nodeid     branchid  chainage  _header  \
#  0    257759.816500_582767.916500         None       NaN  Lateral
#  1                           None  OAF-O-00956       3.0  Lateral
#  2                           None  OAF-O-00956       4.0  Lateral
#  3                           None  OAF-O-01042     114.0  Lateral
#  4                           None  OAF-O-01042     115.0  Lateral
#  ..                           ...          ...       ...      ...
#  138                         None  OAF-O-00081     387.0  Lateral
#  139                         None  OAF-O-00081     400.0  Lateral
#  140                         None  OAF-O-00081     386.0  Lateral
#  141                         None  OAF-O-00081     385.0  Lateral
#  142                         None  OAF-O-00081     402.0  Lateral
#
#                            geometry
#  0                      POINT EMPTY
#  1    POINT (257757.255 582766.354)
#  2    POINT (257756.402 582765.834)
#  3    POINT (253607.965 579899.054)
#  4    POINT (253607.938 579898.054)
#  ..                             ...
#  138  POINT (253215.473 579868.336)
#  139  POINT (253202.477 579868.668)
#  140  POINT (253216.472 579868.311)
#  141  POINT (253217.472 579868.285)
#  142  POINT (253200.478 579868.719)
#
#  [143 rows x 7 columns]}
